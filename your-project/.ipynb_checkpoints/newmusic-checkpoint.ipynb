# %%
# Libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
glweek1=pd.read_csv('datasets/regional-global-weekly-2018-01-12--2018-01-19.csv')
glweek7=pd.read_csv('datasets/regional-global-weekly-2018-07-13--2018-07-20.csv')
USweek1=pd.read_csv('datasets/regional-us-weekly-2018-01-12--2018-01-19.csv')
USweek7=pd.read_csv('datasets/regional-us-weekly-2018-07-13--2018-07-20.csv')
UKweek1=pd.read_csv('datasets/regional-gb-weekly-2018-01-12--2018-01-19.csv')
UKweek7=pd.read_csv('datasets/regional-gb-weekly-2018-07-13--2018-07-20.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c4bb50e7308c> in <module>
# ----> 1 glweek1=pd.read_csv('datasets/regional-global-weekly-2018-01-12--2018-01-19.csv')
#       2 glweek7=pd.read_csv('datasets/regional-global-weekly-2018-07-13--2018-07-20.csv')
#       3 USweek1=pd.read_csv('datasets/regional-us-weekly-2018-01-12--2018-01-19.csv')
#       4 USweek7=pd.read_csv('datasets/regional-us-weekly-2018-07-13--2018-07-20.csv')
#       5 UKweek1=pd.read_csv('datasets/regional-gb-weekly-2018-01-12--2018-01-19.csv')
#
# ...

# %%
GL1=glweek1.drop(['URL','Position'], axis=1)
GL7=glweek7.drop(['URL','Position'], axis=1)
US1=USweek1.drop(['URL','Position'], axis=1)
US7=USweek7.drop(['URL','Position'], axis=1)
GB1=UKweek1.drop(['URL','Position'], axis=1)
GB7=UKweek7.drop(['URL','Position'], axis=1)

GL1.head()
# Out:
#                        Track Name          Artist   Streams
# 0       Havana (feat. Young Thug)  Camila Cabello  30948101
# 1                        rockstar     Post Malone  27643632
# 2        River (feat. Ed Sheeran)          Eminem  22610091
# 3               Never Be the Same  Camila Cabello  22147865
# 4  Finesse - Remix; feat. Cardi B      Bruno Mars  20387864

# %%
total = GL1['Streams'].sum()



totalUS = US1['Streams'].sum()
totalGB = GB1['Streams'].sum()
print(total)
print(totalUS)
print(totalGB)
# Out:
# 1510938244
# 503339880
# 134488545

# %%
GL1['Impact GL%'] = GL1['Streams']/total*100
US1['Impact US%'] = US1['Streams']/totalUS*100
GB1['Impact GB%'] = GB1['Streams']/totalGB*100

# %%
GL1['Impact GL%']=GL1['Impact GL%'].apply(lambda x: round(x,2)) #list(map(lambda v:v [:5] , GL1['Impact']))
US1['Impact US%']=US1['Impact US%'].apply(lambda x: round(x,2))
GB1['Impact GB%']=GB1['Impact GB%'].apply(lambda x: round(x,2))
GL1.head()
# Out:
#                        Track Name          Artist   Streams  Impact GL%
# 0       Havana (feat. Young Thug)  Camila Cabello  30948101        2.05
# 1                        rockstar     Post Malone  27643632        1.83
# 2        River (feat. Ed Sheeran)          Eminem  22610091        1.50
# 3               Never Be the Same  Camila Cabello  22147865        1.47
# 4  Finesse - Remix; feat. Cardi B      Bruno Mars  20387864        1.35

# %%
#USA_UK= pd.merge(GB1, US1, on=['Track Name', 'Track Name'])
#TOTAL= pd.merge(USA_UK, GL1, on=['Track Name', 'Track Name'])
#T=TOTAL.sort_values(by='Impact GL%', ascending=False)
#TT=T.head(20)

# %%
# Libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
Impact=T.plot(x="Track Name", y=["Impact GB%", "Impact US%",'Impact GL%'])
Streams=T.plot(x="Track Name", y=["Streams_x", "Streams_y",'Streams'])

# %%
# Divide the table in uk, us, gl
GL=GL1.head(51)
US=US1.head(51)
UK=GB1.head(51)

# Per table: Order the table per stream, take only the first 50 positions 
# Count how many songs per author
songs=GL.groupby('Artist').count()
GLL=GL=songs.drop(['Streams','Impact GL%'], axis=1)
GLL=GL.columns= ["Number songs"]
GLL=GL.sort_values(by='Number songs',ascending=False)
# Plot how many songs per author
GL=GL1.head(51)
GLL
# Out:
#                    Number songs
# Artist
# Post Malone                   4
# Camila Cabello                3
# Ed Sheeran                    3
# Kendrick Lamar                2
# Dua Lipa                      2
# G-Eazy                        2
# Piso 21                       1
# Marshmello                    1
# Martin Garrix                 1
# NF                            1
# Natti Natasha                 1
# Offset                        1
# Ozuna                         1
# Anitta                        1
# Portugal. The Man             1
# Maluma                        1
# Rita Ora                      1
# Sam Smith                     1
# Selena Gomez                  1
# Taylor Swift                  1
# Troye Sivan                   1
# ZAYN                          1
# Maroon 5                      1
# Lil Pump                      1
# Luis Fonsi                    1
# Enrique Iglesias              1
# Bebe Rexha                    1
# Bruno Mars                    1
# ...

# %%
Merge= pd.merge(GLL, GL, on='Artist')
M=Merge.head(11)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bfbefd4d2476> in <module>
# ----> 1 Merge= pd.merge(GLL, GL, on='Artist')
#       2 M=Merge.head(11)
#
# NameError: name 'pd' is not defined

# %%
M
# Out:
#             Artist  Number songs                           Track Name  \
# 0      Post Malone             4                             rockstar
# 1      Post Malone             4                         I Fall Apart
# 2      Post Malone             4                          Candy Paint
# 3      Post Malone             4                      Congratulations
# 4   Camila Cabello             3            Havana (feat. Young Thug)
# 5   Camila Cabello             3                    Never Be the Same
# 6   Camila Cabello             3                         Real Friends
# 7       Ed Sheeran             3                              Perfect
# 8       Ed Sheeran             3                         Shape of You
# 9       Ed Sheeran             3  Perfect Duet (Ed Sheeran & Beyoncé)
# 10  Kendrick Lamar             2             All The Stars (with SZA)
#
#      Streams  Impact GL%
# 0   27643632        1.83
# 1   14771304        0.98
# 2   10139620        0.67
# ...
