# %%
import requests
import json 
import pandas as pd
import re 
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = "356d84a9aad04349919883f8c4c82fb8"
client_secret = "bc17e60bd49344b8a36ef153bb5105b9"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
name = "Halsey" #chosen artist
result = sp.search(name) #search query
result['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#   'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#   'id': '26VFTg2z8YR0cCuwLzESi2',
#   'name': 'Halsey',
#   'type': 'artist',
#   'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}]

# %%
lyrics = pd.read_csv('songdata.csv')
lyrics
# Out:
#              artist                                      song  \
# 0              ABBA                     Ahe's My Kind Of Girl
# 1              ABBA                          Andante, Andante
# 2              ABBA                            As Good As New
# 3              ABBA                                      Bang
# 4              ABBA                          Bang-A-Boomerang
# 5              ABBA                        Burning My Bridges
# 6              ABBA                                 Cassandra
# 7              ABBA                                Chiquitita
# 8              ABBA                               Crazy World
# 9              ABBA                           Crying Over You
# 10             ABBA                                     Dance
# 11             ABBA                             Dancing Queen
# 12             ABBA                               Disillusion
# 13             ABBA                     Does Your Mother Know
# ...

# %%
chart = pd.read_csv('regional-global-weekly-2017-01-13--2017-01-20.csv')
chart.columns = ['position','song', 'artist', 'streams', 'url']
chart
# Out:
#      position                                               song  \
# 0    Position                                         Track Name
# 1           1                                       Shape of You
# 2           2                                 Castle on the Hill
# 3           3                                              Paris
# 4           4                                            Starboy
# 5           5  I Don’t Wanna Live Forever (Fifty Shades Darke...
# 6           6            Rockabye (feat. Sean Paul & Anne-Marie)
# 7           7                                             Closer
# 8           8                               Say You Won't Let Go
# 9           9                                   I Feel It Coming
# 10         10                                   Don't Wanna Know
# 11         11                                          Fake Love
# 12         12                Bad and Boujee (feat. Lil Uzi Vert)
# ...

# %%
new_lst = [i for i in chart['song']] #if i in lyrics['artist']#]
oth_lst = [i for i in lyrics['song']]
#chart['artist']
#lyrics['artist']
oth_lst
new_lst
combined_lst = list(filter(lambda x: x in oth_lst, new_lst))
print(combined_lst)
# Out:
# ['Paris', 'Closer', "Don't Wanna Know", 'Fake Love', 'Let Me Love You', '24K Magic', 'Mercy', 'All Night', 'My Way', 'Love Me Now', 'By Your Side', 'Heathens', 'Alone', "Don't Let Me Down", 'Caroline', 'All Time Low', "We Don't Talk Anymore", 'The Greatest', 'Cheap Thrills', 'Photograph', 'Human', 'I Got You', 'Deja Vu', 'Ride', 'Perfect Strangers', 'Faded', 'Love Yourself', 'Sorry', 'Work', "It's Gotta Be You", 'Six Feet Under', 'Needed Me', 'Light', '7 Years', 'September Song', 'This Town', 'Into You', 'Middle', 'Touch', 'Swang', 'Send My Love (To Your New Lover)', 'Fast Car', 'Dangerous', 'Roses', 'Hello', 'The Greatest', 'History', 'Stitches', 'Let It Go', 'Lush Life', 'Reminder', 'The Hills', 'Die For You', 'Hotline Bling', 'Low Life', 'On My Way', 'Million Reasons', 'Party', 'Issues', 'Let Her Go', "Can't Feel My Face", 'I Dare You']

# %%
final_lst = lyrics[lyrics['song'].isin(combined_lst)]
#print(len(final_lst))
#print(len(chart))
final_lst
# Out:
#                          artist                   song  \
# 137                       Adele                  Hello
# 360               Aiza Seguerra                  Sorry
# 488                Alice Cooper            Die For You
# 1045           Barbra Streisand                 Closer
# 2068                 Bruno Mars                  Faded
# 2293                Celine Dion                  Alone
# 2473                Cheap Trick             Let Her Go
# 2741                Chris Brown              Dangerous
# 2880         Christina Aguilera           By Your Side
# 2889         Christina Aguilera                  Hello
# 3614              Dan Fogelberg             Let Her Go
# 3699            David Allan Coe          Cheap Thrills
# 3824               David Guetta              Dangerous
# 4002                Deep Purple      Perfect Strangers
# 4407               Donna Summer              Lush Life
# 4444            Doobie Brothers              Dangerous
# ...
