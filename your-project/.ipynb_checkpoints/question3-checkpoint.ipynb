# %%
# WHICH 10 ARTISTS ON THE TOP CHARTS OF 2018 are closest
# to the mean in valence, loudness, energy, danceability, tempo?

# %%
import pandas as pd

# %%
# import csv
csvfile = "top2018.csv"
df = pd.read_csv(csvfile)

# %%
# select revelant columns
cols = ["name", "artists", "danceability", "energy", "loudness", "tempo"]
df_light = df[cols].copy()
df_light
# Out:
#                                  name       artists  danceability  energy  \
# 0                          God's Plan         Drake         0.754   0.449
# 1                                SAD!  XXXTENTACION         0.740   0.613
# 2          rockstar (feat. 21 Savage)   Post Malone         0.587   0.535
# 3        Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559
# 4                      In My Feelings         Drake         0.835   0.626
# ..                                ...           ...           ...     ...
# 95                  Rewrite The Stars     Zac Efron         0.684   0.619
# 96  I Miss You (feat. Julia Michaels)  Clean Bandit         0.638   0.658
# 97                         No Brainer     DJ Khaled         0.552   0.760
# 98        Dusk Till Dawn - Radio Edit          ZAYN         0.258   0.437
# 99                         Be Alright    Dean Lewis         0.553   0.586
#
#     loudness    tempo
# 0     -9.211   77.169
# 1     -4.880   75.023
# 2     -6.090  159.847
# 3     -8.011  140.124
# 4     -5.833   91.030
# ..       ...      ...
# 95    -7.005  125.046
# 96    -6.318  105.076
# 97    -4.706  135.702
# 98    -6.593  180.043
# 99    -6.319  126.684
#
# [100 rows x 6 columns]

# %%
# calculate averages of each metric
stats = df_light.describe().transpose()
stats
# Out:
#               count       mean        std     min       25%       50%  \
# danceability  100.0    0.71646   0.131070   0.258   0.63550    0.7330
# energy        100.0    0.65906   0.145067   0.296   0.56200    0.6780
# loudness      100.0   -5.67764   1.777577 -10.109  -6.65050   -5.5665
# tempo         100.0  119.90418  28.795984  64.934  95.73075  120.1160
#
#                     75%      max
# danceability    0.79825    0.964
# energy          0.77225    0.909
# loudness       -4.36375   -2.384
# tempo         140.02275  198.075

# %%
# calculate averages of each metric per artist, excluding outliers

# identify outliers
stats['IQR'] = stats['75%']-stats['25%']
outliers = pd.DataFrame(columns=df_light.columns)
for col in stats.index:
    iqr = stats.at[col, 'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col, '25%'] - cutoff
    upper = stats.at[col, '75%'] + cutoff
    results = df_light[(df_light[col]<lower)|(df_light[col]>upper)].copy()
    results['outlier'] = col
    outliers = outliers.append(results)


# get averages, excluding outliers
df_avg = df_light[(df_light["artists"]!="Billie Eilish") & (df_light["artists"]!="Keala Settle") & (df_light["artists"]!="ZAYN")]
danceability_avg = df_avg["danceability"].mean()
energy_avg = df_avg["energy"].mean()
loudness_avg = df_avg["loudness"].mean()
tempo_avg = df_avg["tempo"].mean()

print(danceability_avg, energy_avg, loudness_avg, tempo_avg, outliers)

# Outliers stand out especially for their unusually low value for danceability.
# Out:
# 0.7294123711340206 0.6646288659793814 -5.606041237113403 118.59163917525771           artists  danceability  energy  loudness  \
# 80  Billie Eilish         0.351   0.296   -10.109
# 93   Keala Settle         0.284   0.704    -7.276
# 98           ZAYN         0.258   0.437    -6.593
# 80  Billie Eilish         0.351   0.296   -10.109
#
#                            name       outlier    tempo
# 80         lovely (with Khalid)  danceability  115.284
# 93                   This Is Me  danceability  191.702
# 98  Dusk Till Dawn - Radio Edit  danceability  180.043
# 80         lovely (with Khalid)      loudness  115.284
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
# calculate relative distances to mean for each metric and adding them to see which 10 artists are closer to the mean
df_light["dist_danceability"] = abs((df_light["danceability"] - danceability_avg)/danceability_avg)
df_light["dist_energy"] = abs((df_light["energy"] - energy_avg)/energy_avg)
df_light["dist_loudness"] = abs((df_light["loudness"] - loudness_avg)/loudness_avg)
df_light["dist_tempo"] = abs((df_light["tempo"] - tempo_avg)/tempo_avg)

# sum distances
df_light["diff"] = df_light["dist_danceability"] + df_light["dist_energy"] + df_light["dist_loudness"] + df_light["dist_tempo"]
df_light.sort_values(by=["diff"], ascending=False, inplace=True)

df_light
# Out:
#                                  name        artists  danceability  energy  \
# 80               lovely (with Khalid)  Billie Eilish         0.351   0.296
# 38                            changes   XXXTENTACION         0.669   0.308
# 98        Dusk Till Dawn - Radio Edit           ZAYN         0.258   0.437
# 93                         This Is Me   Keala Settle         0.284   0.704
# 91                         Yes Indeed       Lil Baby         0.964   0.346
# ..                                ...            ...           ...     ...
# 39                         In My Mind         Dynoro         0.694   0.770
# 72  Pray For Me (with Kendrick Lamar)     The Weeknd         0.735   0.677
# 26           Love Lies (with Normani)         Khalid         0.708   0.648
# 24                          New Rules       Dua Lipa         0.762   0.700
# 16               no tears left to cry  Ariana Grande         0.699   0.713
#
#     loudness    tempo  dist_danceability  dist_energy  dist_loudness  \
# 80   -10.109  115.284           0.518791     0.554639       0.803233
# 38   -10.068   64.934           0.082823     0.536583       0.795920
# 98    -6.593  180.043           0.646291     0.342490       0.176053
# 93    -7.276  191.702           0.610645     0.059238       0.297886
# 91    -9.309  119.958           0.321612     0.479409       0.660530
# ..       ...      ...                ...          ...            ...
# 39    -5.335  125.905           0.048549     0.158541       0.048348
# 72    -4.979  100.584           0.007660     0.018614       0.111851
# 26    -5.626  143.955           0.029356     0.025020       0.003560
# 24    -6.021  116.073           0.044677     0.053219       0.074020
# 16    -5.507  121.993           0.041694     0.072779       0.017667
#
#     dist_tempo      diff
# 80    0.027891  1.904554
# 38    0.452457  1.867784
# 98    0.518176  1.683010
# 93    0.616488  1.584257
# 91    0.011522  1.473072
# ..         ...       ...
# 39    0.061668  0.317107
# 72    0.151846  0.289971
# 26    0.213871  0.271807
# 24    0.021238  0.193154
# 16    0.028681  0.160822
#
# [100 rows x 11 columns]

# %%
# which 5 artists have a greater presence in the top chart?
# (index 6 onwards has only 2 songs on the list)
df_top5_popular = df_light.groupby("artists", as_index=False).agg({"name":"count"})
df_top5_popular = df_top5_popular.sort_values(by=["name"], ascending=False).head(5)
top5_popular = list(df_top5_popular["artists"])
top5_popular
# Out:
# ['Post Malone', 'XXXTENTACION', 'Drake', 'Ed Sheeran', 'Marshmello']

# %%
# what characteristics do these artists' songs have that might make them more appealing?

stats2 = df_light[(df_light["artists"].isin(top5_popular))].describe()

print(df_light[(df_light["artists"].isin(top5_popular))])
print(stats2)
# Out:
#                                    name       artists  danceability  energy  \
# 38                              changes  XXXTENTACION         0.669   0.308
# 61                              Nonstop         Drake         0.912   0.412
# 28                       Jocelyn Flores  XXXTENTACION         0.872   0.391
# 0                            God's Plan         Drake         0.754   0.449
# 84  Perfect Duet (Ed Sheeran & Beyonc?)    Ed Sheeran         0.587   0.299
# 9                               FRIENDS    Marshmello         0.626   0.880
# 62       Fuck Love (feat. Trippie Redd)  XXXTENTACION         0.797   0.533
# 64                              Silence    Marshmello         0.520   0.761
# 12                        Nice For What         Drake         0.586   0.909
# 51                              Happier    Marshmello         0.687   0.792
# 29                              Perfect    Ed Sheeran         0.599   0.448
# 2            rockstar (feat. 21 Savage)   Post Malone         0.587   0.535
# 3          Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559
# 25                         Shape of You    Ed Sheeran         0.825   0.652
# 32                         I Fall Apart   Post Malone         0.556   0.538
# 75                          Candy Paint   Post Malone         0.670   0.654
# 76                      Congratulations   Post Malone         0.630   0.804
# 1                                  SAD!  XXXTENTACION         0.740   0.613
# 18                            Moonlight  XXXTENTACION         0.921   0.537
# 94   Everybody Dies In Their Nightmares  XXXTENTACION         0.734   0.570
# 5                            Better Now   Post Malone         0.680   0.563
# 4                        In My Feelings         Drake         0.835   0.626
#
#     loudness    tempo  dist_danceability  dist_energy  dist_loudness  \
# 38   -10.068   64.934           0.082823     0.536583       0.795920
# 61    -8.074  154.983           0.250322     0.380105       0.440232
# 28    -9.144  134.021           0.195483     0.411702       0.631098
# 0     -9.211   77.169           0.033709     0.324435       0.643049
# 84    -7.365   94.992           0.195243     0.550125       0.313761
# 9     -2.384   95.079           0.141775     0.324047       0.574744
# 62    -9.740  131.036           0.092660     0.198049       0.737411
# 64    -3.093  141.971           0.287097     0.145000       0.448274
# 12    -6.474   93.394           0.196614     0.367681       0.154826
# 51    -2.749  100.015           0.058146     0.191642       0.509636
# 29    -6.312   95.050           0.178791     0.325940       0.125928
# 2     -6.090  159.847           0.195243     0.195039       0.086328
# 3     -8.011  140.124           0.013144     0.158929       0.428994
# 25    -3.183   95.977           0.131047     0.019001       0.432220
# 32    -5.408  143.950           0.237743     0.190526       0.035326
# 75    -5.944  180.024           0.081452     0.015992       0.060285
# 76    -4.183  123.146           0.136291     0.209698       0.253841
# 1     -4.880   75.023           0.014515     0.077681       0.129511
# 18    -5.723  128.009           0.262660     0.192030       0.020863
# 94    -7.066  129.953           0.006289     0.142379       0.260426
# 5     -5.843  145.028           0.067743     0.152911       0.042268
# 4     -5.833   91.030           0.144757     0.058121       0.040485
#
#     dist_tempo      diff
# 38    0.452457  1.867784
# 61    0.306863  1.377521
# 28    0.130105  1.368387
# 0     0.349288  1.350481
# 84    0.198999  1.258128
# 9     0.198266  1.238832
# 62    0.104935  1.133055
# 64    0.197142  1.077513
# 12    0.212474  0.931594
# 51    0.156644  0.916068
# 29    0.198510  0.829169
# 2     0.347877  0.824488
# 3     0.181567  0.782635
# 25    0.190693  0.772962
# 32    0.213829  0.677424
# 75    0.518016  0.675745
# 76    0.038404  0.638233
# 1     0.367384  0.589090
# 18    0.079410  0.554963
# 94    0.095802  0.504896
# 5     0.222919  0.485841
# 4     0.232408  0.475771
#        danceability     energy   loudness       tempo  dist_danceability  \
# count     22.000000  22.000000  22.000000   22.000000          22.000000
# mean       0.705727   0.583318  -6.217182  117.943409           0.136525
# std        0.117063   0.169016   2.251332   31.001464           0.085643
# min        0.520000   0.299000 -10.068000   64.934000           0.006289
# 25%        0.605750   0.470000  -7.849500   95.006500           0.071170
# 50%        0.683500   0.561000  -6.017000  125.577500           0.139033
# 75%        0.786250   0.653500  -5.012000  141.509250           0.195423
# max        0.921000   0.909000  -2.384000  180.024000           0.287097
#
#        dist_energy  dist_loudness  dist_tempo       diff
# count    22.000000      22.000000   22.000000  22.000000
# mean      0.234892       0.325701    0.227000   0.924117
# std       0.150159       0.250184    0.119941   0.367527
# min       0.015992       0.020863    0.038404   0.475771
# 25%       0.146978       0.096228    0.162875   0.647611
# 50%       0.193535       0.287094    0.198755   0.826828
# 75%       0.325563       0.494296    0.288249   1.212388
# max       0.550125       0.795920    0.518016   1.867784
