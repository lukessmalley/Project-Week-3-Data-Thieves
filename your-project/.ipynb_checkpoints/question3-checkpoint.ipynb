# %% [markdown]
# # Given Spotify’s annual top 100 song charts, is there a marked preference for songs with specific features/metrics among Spotify users?

# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
# import csv
csvfile = "datasets/top2018.csv"
df = pd.read_csv(csvfile)
df
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0          0.754   0.449   7.0    -9.211   1.0       0.1090        0.0332
# 1          0.740   0.613   8.0    -4.880   1.0       0.1450        0.2580
# 2          0.587   0.535   5.0    -6.090   0.0       0.0898        0.1170
# 3          0.739   0.559   8.0    -8.011   1.0       0.1170        0.5800
# 4          0.835   0.626   1.0    -5.833   1.0       0.1250        0.0589
# ..           ...     ...   ...       ...   ...          ...           ...
# 95         0.684   0.619  10.0    -7.005   1.0       0.0386        0.0716
# 96         0.638   0.658   3.0    -6.318   1.0       0.0456        0.2450
# 97         0.552   0.760   0.0    -4.706   1.0       0.3420        0.0733
# 98         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
# 99         0.553   0.586  11.0    -6.319   1.0       0.0362        0.6970
#
#     instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0           0.000083    0.5520   0.3570   77.169     198973.0             4.0
# 1           0.003720    0.1230   0.4730   75.023     166606.0             4.0
# 2           0.000066    0.1310   0.1400  159.847     218147.0             4.0
# 3           0.000000    0.1120   0.4390  140.124     221440.0             4.0
# 4           0.000060    0.3960   0.3500   91.030     217925.0             4.0
# ..               ...       ...      ...      ...          ...             ...
# 95          0.000000    0.1220   0.2840  125.046     217440.0             4.0
# 96          0.000004    0.0919   0.3300  105.076     205748.0             4.0
# 97          0.000000    0.0865   0.6390  135.702     260000.0             5.0
# 98          0.000001    0.1060   0.0967  180.043     239000.0             4.0
# 99          0.000000    0.0813   0.4430  126.684     196373.0             4.0
#
# [100 rows x 16 columns]

# %%
# select revelant columns
# dropping key and time_signature because of low variance
# and acousticness and liveness because they are not pertinent to the question
cols_to_drop = ["id", "key", "time_signature", "acousticness", "liveness"]
df_light = df.drop(cols_to_drop, axis=1)
df_light
# Out:
#                                  name       artists  danceability  energy  \
# 0                          God's Plan         Drake         0.754   0.449
# 1                                SAD!  XXXTENTACION         0.740   0.613
# 2          rockstar (feat. 21 Savage)   Post Malone         0.587   0.535
# 3        Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559
# 4                      In My Feelings         Drake         0.835   0.626
# ..                                ...           ...           ...     ...
# 95                  Rewrite The Stars     Zac Efron         0.684   0.619
# 96  I Miss You (feat. Julia Michaels)  Clean Bandit         0.638   0.658
# 97                         No Brainer     DJ Khaled         0.552   0.760
# 98        Dusk Till Dawn - Radio Edit          ZAYN         0.258   0.437
# 99                         Be Alright    Dean Lewis         0.553   0.586
#
#     loudness  mode  speechiness  instrumentalness  valence    tempo  \
# 0     -9.211   1.0       0.1090          0.000083   0.3570   77.169
# 1     -4.880   1.0       0.1450          0.003720   0.4730   75.023
# 2     -6.090   0.0       0.0898          0.000066   0.1400  159.847
# 3     -8.011   1.0       0.1170          0.000000   0.4390  140.124
# 4     -5.833   1.0       0.1250          0.000060   0.3500   91.030
# ..       ...   ...          ...               ...      ...      ...
# 95    -7.005   1.0       0.0386          0.000000   0.2840  125.046
# 96    -6.318   1.0       0.0456          0.000004   0.3300  105.076
# 97    -4.706   1.0       0.3420          0.000000   0.6390  135.702
# 98    -6.593   0.0       0.0390          0.000001   0.0967  180.043
# 99    -6.319   1.0       0.0362          0.000000   0.4430  126.684
#
#     duration_ms
# 0      198973.0
# 1      166606.0
# 2      218147.0
# 3      221440.0
# 4      217925.0
# ..          ...
# 95     217440.0
# 96     205748.0
# 97     260000.0
# 98     239000.0
# 99     196373.0
#
# [100 rows x 11 columns]

# %%
# calculate averages of each metric
stats = df_light.describe().transpose()
stats
# Out:
#                   count           mean           std         min  \
# danceability      100.0       0.716460      0.131070      0.2580
# energy            100.0       0.659060      0.145067      0.2960
# loudness          100.0      -5.677640      1.777577    -10.1090
# mode              100.0       0.590000      0.494311      0.0000
# speechiness       100.0       0.115569      0.104527      0.0232
# instrumentalness  100.0       0.001584      0.013449      0.0000
# valence           100.0       0.484443      0.206145      0.0796
# tempo             100.0     119.904180     28.795984     64.9340
# duration_ms       100.0  205206.780000  40007.893404  95467.0000
#
#                            25%           50%            75%         max
# danceability           0.63550       0.73300       0.798250       0.964
# energy                 0.56200       0.67800       0.772250       0.909
# loudness              -6.65050      -5.56650      -4.363750      -2.384
# mode                   0.00000       1.00000       1.000000       1.000
# speechiness            0.04535       0.07495       0.137000       0.530
# instrumentalness       0.00000       0.00000       0.000031       0.134
# valence                0.34100       0.47050       0.641500       0.931
# tempo                 95.73075     120.11600     140.022750     198.075
# duration_ms       184680.00000  205047.50000  221493.250000  417920.000

# %%
df_light = df_light.sort_values(by=["danceability"])

fig, axs = plt.subplots(2, 3, figsize=(20, 10))
axs[0, 0].hist(df_light['danceability'], 30, range=[-0.1, 1.1], facecolor='gray', align='mid')
axs[0, 1].hist(df_light['loudness'], 30, range=[-60.5, 0.5], facecolor='gray', align='mid')
axs[0, 2].hist(df_light['energy'], 30, range=[-0.1, 1.1], facecolor='gray', align='mid')
axs[1, 0].hist(df_light['speechiness'], 30, range=[-0.1, 1.1], facecolor='gray', align='mid')
axs[1, 1].hist(df_light['instrumentalness'], 30, range=[-0.1, 1.1], facecolor='gray', align='mid')
axs[1, 2].hist(df_light['tempo'], 30, range=[0, 220], facecolor='gray', align='mid')
plt.show()

# %% [markdown]
# ## Conclusions:
#
# - **Danceability:**
# Scale 0-1: mean=0.71 with std=0.13.
# More danceable is preferred.
#
# - **Loudness:**
# Scale -60-0: mean=-6 with std=1.7.
# Louder is preferred.
#
# - **Energy:**
# Scale 0-1: mean=0.65 with std=0.14.
# Neither excessive nor lacking energy is preferred.
#
# - **Speechiness:**
# Scale 0-1 (songs usually within the 0-0.66 range): mean=0.11 with std=0.1.
# Less speechiness is preferred (p.e.: rap would be 0.33-0.66).
#
# - **Instrumentalness:**
# Scale 0-1 (instrumental only is usually >0.5): mean=0.001 with std=0.01.
# Songs with vocals are definitely preferred.
#
# - **Tempo:**
# Usually 20-200: mean=119.
# Songs in the _allegro_ region of tempo are preferred (not too fast but not slow).
#
# - **Valence:**
# Scale 0-1: mean=0.48 with std=0.2.
# Both positive- and negative-sounding songs are equally preferred.
#
# - **Mode:**
# Scale 0-1: mean 0.59 with std=0.49.
# Both major and minor modes are equally preferred, confirming valence data.

# %%
# calculate averages of each metric per artist, excluding outliers

# identify outliers
stats['IQR'] = stats['75%']-stats['25%']
outliers = pd.DataFrame(columns=df_light.columns)
for col in stats.index:
    iqr = stats.at[col, 'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col, '25%'] - cutoff
    upper = stats.at[col, '75%'] + cutoff
    results = df_light[(df_light[col]<lower)|(df_light[col]>upper)].copy()
    results['outlier'] = col
    outliers = outliers.append(results)


# get averages, excluding outliers
df_avg = df_light[(df_light["artists"]!="Billie Eilish") & (df_light["artists"]!="Keala Settle") & (df_light["artists"]!="ZAYN")].copy()
danceability_avg = df_avg["danceability"].mean()
energy_avg = df_avg["energy"].mean()
loudness_avg = df_avg["loudness"].mean()
tempo_avg = df_avg["tempo"].mean()

print(danceability_avg, energy_avg, loudness_avg, tempo_avg)
outliers
# Outliers stand out especially for their unusually low value for danceability.
# Out:
# 0.7294123711340206 0.6646288659793815 -5.606041237113403 118.59163917525774
#                 artists  danceability  duration_ms  energy  instrumentalness  \
# 98                 ZAYN         0.258     239000.0   0.437          0.000001
# 93         Keala Settle         0.284     234707.0   0.704          0.000115
# 80        Billie Eilish         0.351     200186.0   0.296          0.000000
# 80        Billie Eilish         0.351     200186.0   0.296          0.000000
# 97            DJ Khaled         0.552     260000.0   0.760          0.000000
# 35         benny blanco         0.560     173800.0   0.680          0.000000
# 23  5 Seconds of Summer         0.596     203418.0   0.854          0.000000
# 40               Eminem         0.748     221013.0   0.749          0.000000
# 55              6ix9ine         0.931     179405.0   0.387          0.000000
# 91             Lil Baby         0.964     142273.0   0.346          0.000000
# 93         Keala Settle         0.284     234707.0   0.704          0.000115
# 12                Drake         0.586     210747.0   0.909          0.000109
# 17            Nicky Jam         0.595     173628.0   0.773          0.001080
# 43      Imagine Dragons         0.605     187147.0   0.822          0.134000
# 36       Camila Cabello         0.637     226973.0   0.713          0.000637
# 15       Kendrick Lamar         0.698     232187.0   0.633          0.000194
# 1          XXXTENTACION         0.740     166606.0   0.613          0.003720
# 57          Loud Luxury         0.752     163216.0   0.764          0.000094
# 0                 Drake         0.754     198973.0   0.449          0.000083
# 62         XXXTENTACION         0.797     146520.0   0.533          0.000152
# 71    Portugal. The Man         0.801     163253.0   0.795          0.000113
# 78        Natti Natasha         0.814     232550.0   0.813          0.000093
# 89              Wolfine         0.909     197120.0   0.493          0.000147
# 61                Drake         0.912     238614.0   0.412          0.013000
# 18         XXXTENTACION         0.921     135090.0   0.537          0.004040
# 38         XXXTENTACION         0.669     121887.0   0.308          0.000000
# 94         XXXTENTACION         0.734      95467.0   0.570          0.000021
# 42         Travis Scott         0.834     312820.0   0.730          0.000000
# 28         XXXTENTACION         0.872     119133.0   0.391          0.000004
# 21           Nio Garcia         0.903     417920.0   0.675          0.000013
#
#     loudness  mode                                    name           outlier  \
# 98    -6.593   0.0             Dusk Till Dawn - Radio Edit      danceability
# 93    -7.276   1.0                              This Is Me      danceability
# 80   -10.109   0.0                    lovely (with Khalid)      danceability
# 80   -10.109   0.0                    lovely (with Khalid)          loudness
# 97    -4.706   1.0                              No Brainer       speechiness
# 35    -7.648   0.0         Eastside (with Halsey & Khalid)       speechiness
# 23    -5.114   0.0                              Youngblood       speechiness
# 40    -5.916   0.0                River (feat. Ed Sheeran)       speechiness
# 55    -9.127   1.0  FEFE (feat. Nicki Minaj & Murda Beatz)       speechiness
# 91    -9.309   0.0                              Yes Indeed       speechiness
# 93    -7.276   1.0                              This Is Me  instrumentalness
# 12    -6.474   1.0                           Nice For What  instrumentalness
# 17    -4.736   0.0                                       X  instrumentalness
# 43    -4.833   1.0                                 Thunder  instrumentalness
# 36    -4.333   1.0                       Never Be the Same  instrumentalness
# 15    -4.946   1.0                All The Stars (with SZA)  instrumentalness
# 1     -4.880   1.0                                    SAD!  instrumentalness
# 57    -4.399   1.0                     Body (feat. brando)  instrumentalness
# 0     -9.211   1.0                              God's Plan  instrumentalness
# 62    -9.740   0.0          Fuck Love (feat. Trippie Redd)  instrumentalness
# 71    -5.115   0.0                           Feel It Still  instrumentalness
# 78    -3.023   0.0                                Criminal  instrumentalness
# 89    -6.688   1.0                                   Bella  instrumentalness
# 61    -8.074   1.0                                 Nonstop  instrumentalness
# 18    -5.723   0.0                               Moonlight  instrumentalness
# 38   -10.068   1.0                                 changes       duration_ms
# 94    -7.066   0.0      Everybody Dies In Their Nightmares       duration_ms
# 42    -3.714   1.0                              SICKO MODE       duration_ms
# 28    -9.144   0.0                          Jocelyn Flores       duration_ms
# 21    -3.445   0.0                         Te Bot? - Remix       duration_ms
#
#     speechiness    tempo  valence
# 98       0.0390  180.043   0.0967
# 93       0.1860  191.702   0.1000
# 80       0.0333  115.284   0.1200
# 80       0.0333  115.284   0.1200
# 97       0.3420  135.702   0.6390
# 35       0.3210   89.391   0.3190
# 23       0.4630  120.274   0.1520
# 40       0.5160   90.090   0.6590
# 55       0.4120  125.978   0.3760
# 91       0.5300  119.958   0.5620
# 93       0.1860  191.702   0.1000
# 12       0.0705   93.394   0.7570
# 17       0.0549  180.073   0.7110
# 43       0.0438  167.997   0.2880
# 36       0.0747  129.923   0.2430
# 15       0.0597   96.924   0.5520
# 1        0.1450   75.023   0.4730
# 57       0.0380  121.958   0.5820
# 0        0.1090   77.169   0.3570
# 62       0.0412  131.036   0.3290
# 71       0.0504   79.028   0.7540
# 78       0.0561   79.997   0.8390
# 89       0.0735   94.016   0.8440
# 61       0.1240  154.983   0.4220
# 18       0.0804  128.009   0.7110
# 38       0.0290   64.934   0.5200
# 94       0.1330  129.953   0.6890
# 42       0.2220  155.008   0.4460
# 28       0.2420  134.021   0.4370
# 21       0.2140   96.507   0.4420

# %%
# calculate relative distances to mean for each metric and adding them to see which 10 artists are closer to the mean
df_light["dist_danceability"] = abs((df_light["danceability"] - danceability_avg)/danceability_avg)
df_light["dist_energy"] = abs((df_light["energy"] - energy_avg)/energy_avg)
df_light["dist_loudness"] = abs((df_light["loudness"] - loudness_avg)/loudness_avg)
df_light["dist_tempo"] = abs((df_light["tempo"] - tempo_avg)/tempo_avg)

# sum distances
df_light["diff"] = df_light["dist_danceability"] + df_light["dist_energy"] + df_light["dist_loudness"] + df_light["dist_tempo"]
df_light.sort_values(by=["diff"], ascending=False, inplace=True)

df_light
# Out:
#                                  name        artists  danceability  energy  \
# 80               lovely (with Khalid)  Billie Eilish         0.351   0.296
# 38                            changes   XXXTENTACION         0.669   0.308
# 98        Dusk Till Dawn - Radio Edit           ZAYN         0.258   0.437
# 93                         This Is Me   Keala Settle         0.284   0.704
# 91                         Yes Indeed       Lil Baby         0.964   0.346
# ..                                ...            ...           ...     ...
# 39                         In My Mind         Dynoro         0.694   0.770
# 72  Pray For Me (with Kendrick Lamar)     The Weeknd         0.735   0.677
# 26           Love Lies (with Normani)         Khalid         0.708   0.648
# 24                          New Rules       Dua Lipa         0.762   0.700
# 16               no tears left to cry  Ariana Grande         0.699   0.713
#
#     loudness  mode  speechiness  instrumentalness  valence    tempo  \
# 80   -10.109   0.0       0.0333          0.000000   0.1200  115.284
# 38   -10.068   1.0       0.0290          0.000000   0.5200   64.934
# 98    -6.593   0.0       0.0390          0.000001   0.0967  180.043
# 93    -7.276   1.0       0.1860          0.000115   0.1000  191.702
# 91    -9.309   0.0       0.5300          0.000000   0.5620  119.958
# ..       ...   ...          ...               ...      ...      ...
# 39    -5.335   1.0       0.1490          0.000011   0.1630  125.905
# 72    -4.979   1.0       0.0930          0.000022   0.1880  100.584
# 26    -5.626   1.0       0.0449          0.000000   0.3380  143.955
# 24    -6.021   0.0       0.0694          0.000016   0.6080  116.073
# 16    -5.507   0.0       0.0594          0.000003   0.3540  121.993
#
#     duration_ms  dist_danceability  dist_energy  dist_loudness  dist_tempo  \
# 80     200186.0           0.518791     0.554639       0.803233    0.027891
# 38     121887.0           0.082823     0.536583       0.795920    0.452457
# 98     239000.0           0.646291     0.342490       0.176053    0.518176
# 93     234707.0           0.610645     0.059238       0.297886    0.616488
# 91     142273.0           0.321612     0.479409       0.660530    0.011522
# ..          ...                ...          ...            ...         ...
# 39     184560.0           0.048549     0.158541       0.048348    0.061668
# 72     211440.0           0.007660     0.018614       0.111851    0.151846
# 26     201707.0           0.029356     0.025020       0.003560    0.213871
# 24     209320.0           0.044677     0.053219       0.074020    0.021238
# 16     205920.0           0.041694     0.072779       0.017667    0.028681
#
#         diff
# 80  1.904554
# 38  1.867784
# 98  1.683010
# 93  1.584257
# 91  1.473072
# ..       ...
# 39  0.317107
# 72  0.289971
# 26  0.271807
# 24  0.193154
# 16  0.160822
#
# [100 rows x 16 columns]

# %%
# which 5 artists have a greater presence in the top chart?
# (index 6 onwards has only 2 songs on the list)
df_top5_popular = df_light.groupby("artists", as_index=False).agg({"name":"count"})
df_top5_popular = df_top5_popular.sort_values(by=["name"], ascending=False).head(5)
top5_popular = list(df_top5_popular["artists"])
top5_popular
# Out:
# ['Post Malone', 'XXXTENTACION', 'Drake', 'Ed Sheeran', 'Marshmello']

# %%
# what characteristics do these artists' songs have that might make them more appealing?

stats2 = df_light[(df_light["artists"].isin(top5_popular))].describe()

df_light[(df_light["artists"].isin(top5_popular))]
# Out:
#                                    name       artists  danceability  energy  \
# 38                              changes  XXXTENTACION         0.669   0.308
# 61                              Nonstop         Drake         0.912   0.412
# 28                       Jocelyn Flores  XXXTENTACION         0.872   0.391
# 0                            God's Plan         Drake         0.754   0.449
# 84  Perfect Duet (Ed Sheeran & Beyonc?)    Ed Sheeran         0.587   0.299
# 9                               FRIENDS    Marshmello         0.626   0.880
# 62       Fuck Love (feat. Trippie Redd)  XXXTENTACION         0.797   0.533
# 64                              Silence    Marshmello         0.520   0.761
# 12                        Nice For What         Drake         0.586   0.909
# 51                              Happier    Marshmello         0.687   0.792
# 29                              Perfect    Ed Sheeran         0.599   0.448
# 2            rockstar (feat. 21 Savage)   Post Malone         0.587   0.535
# 3          Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559
# 25                         Shape of You    Ed Sheeran         0.825   0.652
# 32                         I Fall Apart   Post Malone         0.556   0.538
# 75                          Candy Paint   Post Malone         0.670   0.654
# 76                      Congratulations   Post Malone         0.630   0.804
# 1                                  SAD!  XXXTENTACION         0.740   0.613
# 18                            Moonlight  XXXTENTACION         0.921   0.537
# 94   Everybody Dies In Their Nightmares  XXXTENTACION         0.734   0.570
# 5                            Better Now   Post Malone         0.680   0.563
# 4                        In My Feelings         Drake         0.835   0.626
#
#     loudness  mode  speechiness  instrumentalness  valence    tempo  \
# 38   -10.068   1.0       0.0290          0.000000    0.520   64.934
# 61    -8.074   1.0       0.1240          0.013000    0.422  154.983
# 28    -9.144   0.0       0.2420          0.000004    0.437  134.021
# 0     -9.211   1.0       0.1090          0.000083    0.357   77.169
# 84    -7.365   1.0       0.0263          0.000000    0.356   94.992
# 9     -2.384   0.0       0.0504          0.000000    0.534   95.079
# 62    -9.740   0.0       0.0412          0.000152    0.329  131.036
# 64    -3.093   1.0       0.0853          0.000005    0.286  141.971
# 12    -6.474   1.0       0.0705          0.000109    0.757   93.394
# 51    -2.749   1.0       0.0452          0.000000    0.671  100.015
# 29    -6.312   1.0       0.0232          0.000000    0.168   95.050
# 2     -6.090   0.0       0.0898          0.000066    0.140  159.847
# 3     -8.011   1.0       0.1170          0.000000    0.439  140.124
# 25    -3.183   0.0       0.0802          0.000000    0.931   95.977
# 32    -5.408   0.0       0.0382          0.000000    0.291  143.950
# 75    -5.944   1.0       0.1530          0.000001    0.438  180.024
# 76    -4.183   1.0       0.0363          0.000000    0.492  123.146
# 1     -4.880   1.0       0.1450          0.003720    0.473   75.023
# 18    -5.723   0.0       0.0804          0.004040    0.711  128.009
# 94    -7.066   0.0       0.1330          0.000021    0.689  129.953
# 5     -5.843   1.0       0.0454          0.000000    0.374  145.028
# 4     -5.833   1.0       0.1250          0.000060    0.350   91.030
#
#     duration_ms  dist_danceability  dist_energy  dist_loudness  dist_tempo  \
# 38     121887.0           0.082823     0.536583       0.795920    0.452457
# 61     238614.0           0.250322     0.380105       0.440232    0.306863
# 28     119133.0           0.195483     0.411702       0.631098    0.130105
# 0      198973.0           0.033709     0.324435       0.643049    0.349288
# 84     259550.0           0.195243     0.550125       0.313761    0.198999
# 9      202621.0           0.141775     0.324047       0.574744    0.198266
# 62     146520.0           0.092660     0.198049       0.737411    0.104935
# 64     180823.0           0.287097     0.145000       0.448274    0.197142
# 12     210747.0           0.196614     0.367681       0.154826    0.212474
# 51     214290.0           0.058146     0.191642       0.509636    0.156644
# 29     263400.0           0.178791     0.325940       0.125928    0.198510
# 2      218147.0           0.195243     0.195039       0.086328    0.347877
# 3      221440.0           0.013144     0.158929       0.428994    0.181567
# 25     233713.0           0.131047     0.019001       0.432220    0.190693
# 32     223347.0           0.237743     0.190526       0.035326    0.213829
# 75     227533.0           0.081452     0.015992       0.060285    0.518016
# 76     220293.0           0.136291     0.209698       0.253841    0.038404
# 1      166606.0           0.014515     0.077681       0.129511    0.367384
# 18     135090.0           0.262660     0.192030       0.020863    0.079410
# 94      95467.0           0.006289     0.142379       0.260426    0.095802
# 5      231267.0           0.067743     0.152911       0.042268    0.222919
# 4      217925.0           0.144757     0.058121       0.040485    0.232408
#
#         diff
# 38  1.867784
# 61  1.377521
# 28  1.368387
# 0   1.350481
# 84  1.258128
# 9   1.238832
# 62  1.133055
# 64  1.077513
# 12  0.931594
# 51  0.916068
# 29  0.829169
# 2   0.824488
# 3   0.782635
# 25  0.772962
# 32  0.677424
# 75  0.675745
# 76  0.638233
# 1   0.589090
# 18  0.554963
# 94  0.504896
# 5   0.485841
# 4   0.475771

# %%
stats2
# Out:
#        danceability     energy   loudness       mode  speechiness  \
# count     22.000000  22.000000  22.000000  22.000000    22.000000
# mean       0.705727   0.583318  -6.217182   0.636364     0.085882
# std        0.117063   0.169016   2.251332   0.492366     0.054067
# min        0.520000   0.299000 -10.068000   0.000000     0.023200
# 25%        0.605750   0.470000  -7.849500   0.000000     0.042200
# 50%        0.683500   0.561000  -6.017000   1.000000     0.080300
# 75%        0.786250   0.653500  -5.012000   1.000000     0.122250
# max        0.921000   0.909000  -2.384000   1.000000     0.242000
#
#        instrumentalness    valence       tempo    duration_ms  \
# count         22.000000  22.000000   22.000000      22.000000
# mean           0.000966   0.462045  117.943409  197608.454545
# std            0.002917   0.193670   31.001464   46966.368744
# min            0.000000   0.140000   64.934000   95467.000000
# 25%            0.000000   0.351500   95.006500  170160.250000
# 50%            0.000003   0.437500  125.577500  216107.500000
# 75%            0.000079   0.530500  141.509250  226486.500000
# max            0.013000   0.931000  180.024000  263400.000000
#
#        dist_danceability  dist_energy  dist_loudness  dist_tempo       diff
# count          22.000000    22.000000      22.000000   22.000000  22.000000
# mean            0.136525     0.234892       0.325701    0.227000   0.924117
# std             0.085643     0.150159       0.250184    0.119941   0.367527
# min             0.006289     0.015992       0.020863    0.038404   0.475771
# 25%             0.071170     0.146978       0.096228    0.162875   0.647611
# 50%             0.139033     0.193535       0.287094    0.198755   0.826828
# 75%             0.195423     0.325563       0.494296    0.288249   1.212388
# max             0.287097     0.550125       0.795920    0.518016   1.867784
