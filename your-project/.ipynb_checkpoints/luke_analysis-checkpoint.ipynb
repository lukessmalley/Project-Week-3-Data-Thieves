# %%
import pandas as pd
import re

# %%
songs = pd.read_csv('song_analysis.csv')
songs
# Out:
#     Unnamed: 0                     id                   track_name  \
# 0            0  6DCZcSspjsKoFjzjrWoCd                   god's plan
# 1            1  3ee8Jmje8o58CHK66QrVC                         sad!
# 2            2  0e7ipj03S05BNilyu5bRz                     rockstar
# 3            3  3swc6WTsr7rl9DqQKQA55                       psycho
# 4            4  2G7V7zsVDxg1yRsu7Ew9R               in my feelings
# ..         ...                    ...                          ...
# 95          95  630sXRhIcfwr2e4RdNtjK            rewrite the stars
# 96          96  2xmrfQpmS2iJExTlklLoA                   i miss you
# 97          97  5WvAo7DNuPRmk4APhdPzi                   no brainer
# 98          98  1j4kHkkpqZRBwE0A4CN4Y  dusk till dawn - radio edit
# 99          99  3EPXxR3ImUwfayaurPi3c                   be alright
#
#          artists  danceability  energy  key  loudness  mode  speechiness  \
# 0          Drake         0.754   0.449    7    -9.211     1       0.1090
# 1   XXXTENTACION         0.740   0.613    8    -4.880     1       0.1450
# 2    Post Malone         0.587   0.535    5    -6.090     0       0.0898
# 3    Post Malone         0.739   0.559    8    -8.011     1       0.1170
# 4          Drake         0.835   0.626    1    -5.833     1       0.1250
# ..           ...           ...     ...  ...       ...   ...          ...
# 95     Zac Efron         0.684   0.619   10    -7.005     1       0.0386
# 96  Clean Bandit         0.638   0.658    3    -6.318     1       0.0456
# 97     DJ Khaled         0.552   0.760    0    -4.706     1       0.3420
# 98          ZAYN         0.258   0.437   11    -6.593     0       0.0390
# 99    Dean Lewis         0.553   0.586   11    -6.319     1       0.0362
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.0332          0.000083    0.5520   0.3570   77.169       198973
# 1         0.2580          0.003720    0.1230   0.4730   75.023       166606
# 2         0.1170          0.000066    0.1310   0.1400  159.847       218147
# 3         0.5800          0.000000    0.1120   0.4390  140.124       221440
# 4         0.0589          0.000060    0.3960   0.3500   91.030       217925
# ..           ...               ...       ...      ...      ...          ...
# 95        0.0716          0.000000    0.1220   0.2840  125.046       217440
# 96        0.2450          0.000004    0.0919   0.3300  105.076       205748
# 97        0.0733          0.000000    0.0865   0.6390  135.702       260000
# 98        0.1010          0.000001    0.1060   0.0967  180.043       239000
# 99        0.6970          0.000000    0.0813   0.4430  126.684       196373
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               5
# 98               4
# 99               4
#
# [100 rows x 17 columns]

# %%
#sorted(list(summer_songs['track_name'].unique()))
lst = [i for i in songs['track_name']]
lst
# Out:
# ["god's plan",
#  'sad!',
#  'rockstar',
#  'psycho',
#  'in my feelings',
#  'better now',
#  'i like it',
#  'one kiss',
#  'idgaf',
#  'friends',
#  'havana',
#  'lucid dreams',
#  'nice for what',
#  'girls like you',
#  'the middle',
#  'all the stars',
#  'no tears left to cry',
#  'x',
#  'moonlight',
#  'look alive',
#  'these days',
#  'te bot? - remix',
#  'mine',
#  'youngblood',
#  'new rules',
#  'shape of you',
#  'love lies',
#  'meant to be',
#  'jocelyn flores',
#  'perfect',
#  'taste',
#  'solo',
#  'i fall apart',
#  'nevermind',
#  '?chame la culpa',
#  'eastside',
#  'never be the same',
#  'wolves',
#  'changes',
#  'in my mind',
#  'river',
#  'dura',
#  'sicko mode',
#  'thunder',
#  'me niego',
#  'jackie chan',
#  'finesse  [feat. cardi b]',
#  'back to you - from 13 reasons why ? season 2 soundtrack',
#  'let you down',
#  'call out my name',
#  'ric flair drip',
#  'happier',
#  'too good at goodbyes',
#  'freaky friday',
#  'believer',
#  'fefe',
#  'rise',
#  'body',
#  'xo tour llif3',
#  'sin pijama',
#  '2002',
#  'nonstop',
#  'fuck love',
#  'in my blood',
#  'silence',
#  'god is a woman',
#  'd?jala que vuelva',
#  'flames',
#  'what lovers do',
#  'taki taki',
#  'let me go',
#  'feel it still',
#  'pray for me',
#  'walk it talk it',
#  'him & i',
#  'candy paint',
#  'congratulations',
#  '1, 2, 2003',
#  'criminal',
#  'plug walk',
#  'lovely',
#  'stir fry',
#  'humble.',
#  'vaina loca',
#  'perfect duet',
#  'coraz?n',
#  'young dumb & broke',
#  's?guelo bailando',
#  'downtown',
#  'bella',
#  'promises',
#  'yes indeed',
#  'i like me better',
#  'this is me',
#  'everybody dies in their nightmares',
#  'rewrite the stars',
#  'i miss you',
#  'no brainer',
#  'dusk till dawn - radio edit',
#  'be alright']

# %%
songs['track_name'] = [re.sub(r'\([^)]*\)', '', i).lower().strip() for i in songs['track_name']]
songs['track_name']
songs.to_csv('song_analysis_cleaned.csv')
